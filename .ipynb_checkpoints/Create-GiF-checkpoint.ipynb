# %%
import imageio
import os
from pygifsicle import optimize

gif_path = os.path.join(os.getcwd(),'GIFs','today.gif')
figs_path  = os.path.join(os.getcwd(),'Figs')

# %%
figures = []
for (dirpath, dirnames, filenames) in os.walk(figs_path):
    for file in filenames:
        if 'png' in file:
            figures.append(file)
figures = sorted(figures,key=lambda x: int(os.path.splitext(x)[0]))
print(figures)
# Out:
# ['0.png', '1.png', '2.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png', '10.png', '11.png', '12.png']

# %%
images = []
for fig in figures:
    images.append(imageio.imread(os.path.join(os.getcwd(),'Figs',fig)))

    
with imageio.get_writer(gif_path, mode='I') as writer:
    for fig in figures:
        writer.append_data(imageio.imread(os.path.join(figs_path,fig)))

optimize(gif_path)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-18-5c95cd9f9610> in <module>
#       1 images = []
#       2 for fig in figures:
# ----> 3     images.append(imageio.imread(os.path.join(os.getcwd(),'Figs',fig)))
#       4 imageio.mimsave(os.path.join(os.getcwd(),'GIFs',(str(len(figures))+'.gif')), images)
#
# ~\Anaconda3\envs\general-maps\lib\site-packages\imageio\core\functions.py in imread(uri, format, **kwargs)
#     264     reader = read(uri, format, "i", **kwargs)
#     265     with reader:
# --> 266         return reader.get_data(0)
#     267
#     268
#
# ~\Anaconda3\envs\general-maps\lib\site-packages\imageio\core\format.py in get_data(self, index, **kwargs)
#     337             self._BaseReaderWriter_last_index = index
#     338             try:
# --> 339                 im, meta = self._get_data(index, **kwargs)
#     340             except StopIteration:
#     341                 raise IndexError(index)
#
# ~\Anaconda3\envs\general-maps\lib\site-packages\imageio\plugins\pillow.py in _get_data(self, index)
#     301
#     302         def _get_data(self, index):
# --> 303             im, info = PillowFormat.Reader._get_data(self, index)
#     304             if not self.request.kwargs.get("ignoregamma", True):
#     305                 # The gamma value in the file represents the gamma factor for the
#
# ~\Anaconda3\envs\general-maps\lib\site-packages\imageio\plugins\pillow.py in _get_data(self, index)
#     180                 self._im.palette.rawmode_saved = self._im.palette.rawmode
#     181             self._im.getdata()[0]
# --> 182             im = pil_get_frame(self._im, **self._kwargs)
#     183             return im, self._im.info
#     184
#
# ~\Anaconda3\envs\general-maps\lib\site-packages\imageio\plugins\pillow.py in pil_get_frame(im, is_gray, as_gray, mode, dtype)
#     761                 frame = im.convert("RGB")
#     762     elif "A" in im.mode:
# --> 763         frame = im.convert("RGBA")
#     764     elif im.mode == "CMYK":
#     765         frame = im.convert("RGB")
#
# ~\Anaconda3\envs\general-maps\lib\site-packages\PIL\Image.py in convert(self, mode, matrix, dither, palette, colors)
#     880                 mode = "RGB"
#     881         if not mode or (mode == self.mode and not matrix):
# --> 882             return self.copy()
#     883
#     884         has_transparency = self.info.get("transparency") is not None
#
# ~\Anaconda3\envs\general-maps\lib\site-packages\PIL\Image.py in copy(self)
#    1083         """
#    1084         self.load()
# -> 1085         return self._new(self.im.copy())
#    1086
#    1087     __copy__ = copy
#
# MemoryError:
